# %%
liked_books = ["6882","331567","8349198","4069","2547","14082","12346651"]

# %%
# !head book_id_map.csv
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# %%
pd.read_csv("goodreads_interactions.csv").head()

# %%
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
csv_book_mapping['0']
# Out:
# '34684622'

# %%
overlap_users = set()

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        book_id = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)

# %%
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
# ------------------------brEAK

# %%
import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#          user_id   book_id rating
# 0              0        12      5
# 1              0        21      5
# 2              0        30      5
# 3              0        45      5
# 4              0         1      5
# ...          ...       ...    ...
# 11060069  876132    149280      0
# 11060070  876132  17879811      0
# 11060071  876132  16104434      0
# 11060072  876132    934051      0
# 11060073  876132   8099854      1
#
# [11060074 rows x 3 columns]

# %%
top_recs = recs["book_id"].value_counts().head(10)

# %%
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#         book_id                                              title  ratings  \
# 401395     5107                             The Catcher in the Rye  2086945
# 463463     4671                                   The Great Gatsby  2758812
# 487026     2547                                        The Prophet   145579
# 615314     5470                                               1984  2023937
# 770177     7613                                        Animal Farm  1928931
# 790927     2657                              To Kill a Mockingbird  3255518
# 876816      865                                      The Alchemist  1342863
# 878545        3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1258258   48855                          The Diary of a Young Girl  2028299
# 1280001    4069                           Man's Search for Meaning   179906
#
#                                                        url  \
# 401395   https://www.goodreads.com/book/show/5107.The_C...
# 463463   https://www.goodreads.com/book/show/4671.The_G...
# 487026   https://www.goodreads.com/book/show/2547.The_P...
# 615314       https://www.goodreads.com/book/show/5470.1984
# 770177   https://www.goodreads.com/book/show/7613.Anima...
# 790927   https://www.goodreads.com/book/show/2657.To_Ki...
# 876816   https://www.goodreads.com/book/show/865.The_Al...
# 878545   https://www.goodreads.com/book/show/3.Harry_Po...
# 1258258  https://www.goodreads.com/book/show/48855.The_...
# 1280001  https://www.goodreads.com/book/show/4069.Man_s...
#
#                                                cover_image  \
# 401395   https://images.gr-assets.com/books/1398034300m...
# 463463   https://images.gr-assets.com/books/1490528560m...
# 487026   https://images.gr-assets.com/books/1355046521m...
# 615314   https://images.gr-assets.com/books/1348990566m...
# 770177   https://images.gr-assets.com/books/1424037542m...
# 790927   https://images.gr-assets.com/books/1361975680m...
# 876816   https://images.gr-assets.com/books/1483412266m...
# 878545   https://images.gr-assets.com/books/1474154022m...
# 1258258  https://images.gr-assets.com/books/1358276407m...
# 1280001  https://images.gr-assets.com/books/1467136625m...
#
#                                                  mod_title
# 401395                              the catcher in the rye
# 463463                                    the great gatsby
# 487026                                         the prophet
# 615314                                                1984
# 770177                                         animal farm
# 790927                               to kill a mockingbird
# 876816                                       the alchemist
# 878545   harry potter and the sorcerers stone harry pot...
# 1258258                          the diary of a young girl
# 1280001                            mans search for meaning

# %%
all_recs = recs["book_id"].value_counts()

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs.head(5)
# Out:
#   book_id  book_count
# 0    2657       12623
# 1    5470       12067
# 2    4069       11800
# 3     865       11782
# 4    4671       11195

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#         book_id  book_count  \
# 7          2547       10703
# 2          4069       11800
# 228        6882        2804
# 12300  16156392         115
# 311      304079        2248
# 18109   8514123          81
# 635       14082        1382
# 18217   9624993          80
# 1620   26530322         652
# 11900  28170940         118
#
#                                                    title  ratings  \
# 7                                            The Prophet   145579
# 2                               Man's Search for Meaning   179906
# 228                                             Papillon    39620
# 12300                               The Dust in Sunlight       69
# 311                                   The Essential Rumi    26829
# 18109                               All the Talk Is Dead       35
# 635                                         Malgudi Days    11777
# 18217     The Mirror and the Light (Thomas Cromwell, #3)       40
# 1620   Are We Smart Enough to Know How Smart Animals ...     2685
# 11900                 Lethal White (Cormoran Strike, #4)      106
#
#                                                      url  \
# 7      https://www.goodreads.com/book/show/2547.The_P...
# 2      https://www.goodreads.com/book/show/4069.Man_s...
# 228    https://www.goodreads.com/book/show/6882.Papillon
# 12300  https://www.goodreads.com/book/show/16156392-t...
# 311    https://www.goodreads.com/book/show/304079.The...
# 18109  https://www.goodreads.com/book/show/8514123-al...
# 635    https://www.goodreads.com/book/show/14082.Malg...
# 18217  https://www.goodreads.com/book/show/9624993-th...
# 1620   https://www.goodreads.com/book/show/26530322-a...
# 11900  https://www.goodreads.com/book/show/28170940-l...
#
#                                              cover_image  \
# 7      https://images.gr-assets.com/books/1355046521m...
# 2      https://images.gr-assets.com/books/1467136625m...
# 228    https://images.gr-assets.com/books/1327865561m...
# 12300  https://images.gr-assets.com/books/1353247047m...
# 311    https://images.gr-assets.com/books/1391414844m...
# 18109  https://s.gr-assets.com/assets/nophoto/book/11...
# 635    https://images.gr-assets.com/books/1455574981m...
# 18217  https://s.gr-assets.com/assets/nophoto/book/11...
# 1620   https://images.gr-assets.com/books/1448044158m...
# 11900  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                                mod_title       score
# 7                                            the prophet  786.886907
# 2                                mans search for meaning  773.959735
# 228                                             papillon  198.445634
# 12300                               the dust in sunlight  191.666667
# 311                                   the essential rumi  188.359760
# 18109                               all the talk is dead  187.457143
# 635                                         malgudi days  162.174068
# 18217         the mirror and the light thomas cromwell 3  160.000000
# 1620   are we smart enough to know how smart animals are  158.325512
# 11900                     lethal white cormoran strike 4  131.358491

# %%
all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False).head(10)
# Out:
#        book_id  book_count                                              title  \
# 7         2547       10703                                        The Prophet
# 2         4069       11800                           Man's Search for Meaning
# 228       6882        2804                                           Papillon
# 311     304079        2248                                 The Essential Rumi
# 635      14082        1382                                       Malgudi Days
# 1620  26530322         652  Are We Smart Enough to Know How Smart Animals ...
# 1203     72910         830                                           The Gift
# 2287  21032488         495      Doors of Stone (The Kingkiller Chronicle, #3)
# 34       52036        6643                                         Siddhartha
# 894   27276428        1047                      The Gene: An Intimate History
#
#       ratings                                                url  \
# 7      145579  https://www.goodreads.com/book/show/2547.The_P...
# 2      179906  https://www.goodreads.com/book/show/4069.Man_s...
# 228     39620  https://www.goodreads.com/book/show/6882.Papillon
# 311     26829  https://www.goodreads.com/book/show/304079.The...
# 635     11777  https://www.goodreads.com/book/show/14082.Malg...
# 1620     2685  https://www.goodreads.com/book/show/26530322-a...
# 1203     5668  https://www.goodreads.com/book/show/72910.The_...
# 2287     2059  https://www.goodreads.com/book/show/21032488-d...
# 34     380353  https://www.goodreads.com/book/show/52036.Sidd...
# 894      9874  https://www.goodreads.com/book/show/27276428-t...
#
#                                             cover_image  \
# 7     https://images.gr-assets.com/books/1355046521m...
# 2     https://images.gr-assets.com/books/1467136625m...
# 228   https://images.gr-assets.com/books/1327865561m...
# 311   https://images.gr-assets.com/books/1391414844m...
# 635   https://images.gr-assets.com/books/1455574981m...
# 1620  https://images.gr-assets.com/books/1448044158m...
# 1203  https://s.gr-assets.com/assets/nophoto/book/11...
# 2287  https://s.gr-assets.com/assets/nophoto/book/11...
# 34    https://images.gr-assets.com/books/1428715580m...
# 894   https://images.gr-assets.com/books/1463591739m...
#
#                                               mod_title       score
# 7                                           the prophet  786.886907
# 2                               mans search for meaning  773.959735
# 228                                            papillon  198.445634
# 311                                  the essential rumi  188.359760
# 635                                        malgudi days  162.174068
# 1620  are we smart enough to know how smart animals are  158.325512
# 1203                                           the gift  121.541990
# 2287          doors of stone the kingkiller chronicle 3  119.001943
# 34                                           siddhartha  116.022350
# 894                        the gene an intimate history  111.019749

# %%
popular_recs = all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)


popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9bb95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bb95_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_9bb95_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_9bb95_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_9bb95_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_9bb95_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_9bb95_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_9bb95_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_9bb95_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9